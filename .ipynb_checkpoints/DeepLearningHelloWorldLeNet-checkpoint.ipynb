# %% [markdown]
# # Deep Learning Hello World! (LeNet-5)

# %% [markdown]
# Objective: To be able to implement LeNet-5 for MNIST Classification

# %% [markdown]
# Step 1: Taking care of the imports which includes numpy, datasets, models, layers, optimizers, and utils. <br />
# You will also be able to tell if your set-up is correct/complete.

# %%
import tensorflow as tf
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-20-b1a3bb2cbc8b> in <module>
#       2
#       3 gpu = tf.config.experimental.list_physical_devices('GPU')
# ----> 4 tf.config.experimental.set_memory_growth(gpu,True )
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/framework/config.py in set_memory_growth(device, enable)
#     452     enable: Whether to enable or disable memory growth
#     453   """
# --> 454   context.context().set_memory_growth(device, enable)
#     455
#     456
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in set_memory_growth(self, dev, enable)
#    1216
#    1217     if dev not in self._physical_devices:
# -> 1218       raise ValueError("Unrecognized device: %s" % repr(dev))
#    1219
#    1220     if dev in self._virtual_device_map:
#
# ValueError: Unrecognized device: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import model_from_json
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
import numpy as np
import time  # for duration logs

from IPython.display import Image     # for displaying images
from IPython.core.display import HTML 

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]
tf.debugging.set_log_device_placement(True)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1832425997733859818
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1681964551745047684
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11323765556
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4470128420887417294
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:06:00.0, compute capability: 3.7"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 11323765556
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 964366534253394446
# physical_device_desc: "device: 1, name: Tesla K80, pci bus id: 0000:07:00.0, compute capability: 3.7"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 11323765556
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 13252755658448113731
# physical_device_desc: "device: 2, name: Tesla K80, pci bus id: 0000:0d:00.0, compute capability: 3.7"
# , name: "/device:GPU:3"
# device_type: "GPU"
# memory_limit: 128778240
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 13164445703434743114
# physical_device_desc: "device: 3, name: Tesla K80, pci bus id: 0000:0e:00.0, compute capability: 3.7"
# , name: "/device:GPU:4"
# device_type: "GPU"
# memory_limit: 11323765556
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 9075403183548965978
# physical_device_desc: "device: 4, name: Tesla K80, pci bus id: 0000:86:00.0, compute capability: 3.7"
# , name: "/device:GPU:5"
# device_type: "GPU"
# memory_limit: 6777723290
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4295875709862070062
# physical_device_desc: "device: 5, name: Tesla K80, pci bus id: 0000:87:00.0, compute capability: 3.7"
# , name: "/device:GPU:6"
# device_type: "GPU"
# memory_limit: 11323765556
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 394400694317386001
# physical_device_desc: "device: 6, name: Tesla K80, pci bus id: 0000:8d:00.0, compute capability: 3.7"
# , name: "/device:GPU:7"
# device_type: "GPU"
# memory_limit: 128778240
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 16478012216219749798
# physical_device_desc: "device: 7, name: Tesla K80, pci bus id: 0000:8e:00.0, compute capability: 3.7"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2666857513428696485
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:1"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8915633092445274407
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:2"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9734840433050722445
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:3"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7664267765601109909
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:4"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2609867406526739812
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:5"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2600353022235634159
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:6"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2445192263039182855
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:7"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 5759462236483919307
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:8"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10756470100770854585
# physical_device_desc: "device: XLA_GPU device"
# ]

# %% [markdown]
# Step 2: Define LeNet-5 CNN model

# %%
Image(url= "https://world4jason.gitbooks.io/research-log/content/deepLearning/CNN/img/lenet.png")
# Out:
# <img src="https://world4jason.gitbooks.io/research-log/content/deepLearning/CNN/img/lenet.png"/>

# %%
class LeNet:
	@staticmethod
	def build(input_shape, classes):
		model = Sequential()
		# CONV => RELU => POOL
		model.add(Conv2D(20, kernel_size=5, padding="same",
			input_shape=input_shape))
		model.add(Activation("relu"))
		model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
		# CONV => RELU => POOL
		model.add(Conv2D(50, kernel_size=5, padding="same"))
		model.add(Activation("relu"))
		model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
		# Flatten => RELU layers
		model.add(Flatten())
		model.add(Dense(500))
		model.add(Activation("relu"))
 
		# a softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		return model

# %% [markdown]
# Step 3: Set-up some constants to be utilized in the training/testing of the model <br\>

# %%
NB_EPOCH = 10 # 250
BATCH_SIZE = 128
VERBOSE = 1
OPTIMIZER = Adam()
VALIDATION_SPLIT=0.2

IMG_ROWS, IMG_COLS = 28, 28 
NB_CLASSES = 10  
INPUT_SHAPE = (1, IMG_ROWS, IMG_COLS)

np.random.seed(1983)  # for reproducibility

# %% [markdown]
# Step 4: Load the MNIST Dataset which are shuffled and split between train and test sets <br\>
# - X_train is 60000 rows of 28x28 values
# - X_test is 10000 rows of 28x28 values

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#K.set_image_dim_ordering()
K.set_image_data_format("channels_first")
print("First 100 train images:")
for k in range(100):
    plt.subplot(10, 10, k+1)      
    plt.gca().axes.get_yaxis().set_visible(False)
    plt.gca().axes.get_xaxis().set_visible(False)
    plt.imshow(X_train[k])
# Out:
# First 100 train images:

# %% [markdown]
# Step 5: Preprocess the input data by reshaping it, converting it to float, and normalizing it [0-1].

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255 
X_test /= 255  

# we need a 60K x [1 x 28 x 28] shape as input to the CONVNET
X_train = X_train[:, np.newaxis, :, :]
X_test = X_test[:, np.newaxis, :, :]

print(X_train.shape, 'train samples')
print(X_test.shape, 'test samples')
# Out:
# (60000, 1, 28, 28) train samples
# (10000, 1, 28, 28) test samples

# %% [markdown]
# Step 6: Convert class vectors to binary class matrices; One-Hot-Encoding (OHE)

# %%
Y_train = to_categorical(y_train, NB_CLASSES)
Y_test = to_categorical(y_test, NB_CLASSES)

# %% [markdown]
# Step 7: Create the model with 3 layers: Input:784 ==> Hidden:128 w/ dropout ==> Hidden:128 w/ dropout ==> Output:10 (with Softmax activation)

# %%
# This messes up the multi-gpu
# model = LeNet.build(input_shape=INPUT_SHAPE, classes=NB_CLASSES)
# model.summary()

# %% [markdown]
# Step 8: Compile the model with categorical_crossentropy loss function, Adam optimizer, and accuracy metric

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer=OPTIMIZER,
#               metrics=['accuracy'])

# %% [markdown]
# Step 9: Perform the training with 128 batch size, 250 epochs, and 20 % of the train data used for validation

# %% [markdown]
# ## SLOW MODEL

# %%
# import time  # for duration logs
# start = time.time()
# history = model.fit(X_train, Y_train,
#                     batch_size=BATCH_SIZE, epochs=NB_EPOCH,
#                     verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# end = time.time()
# elapsed = end - start
# time.strftime("%H:%M:%S", time.gmtime(elapsed))

# %% [markdown]
# ## PARALLEL MODEL (MULTI-GPU) #FAILED

# %%
# from tensorflow.keras.utils import multi_gpu_model
# import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3,4,5,6,7"

# parallel_model = multi_gpu_model(model, gpus=8)  # DID NOT TRAIN ON MULTIGPU
# parallel_model.compile(loss='categorical_crossentropy',
#               optimizer=OPTIMIZER,
#               metrics=['accuracy'])

# parallel_model.fit(X_train, Y_train,
#                     batch_size=BATCH_SIZE, epochs=NB_EPOCH,
#                     verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# %% [markdown]
# ## PARALLEL MODEL (SUCCESS)

# %%
start = time.time()
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:6", "/gpu:7"]) # 00:01:13' for 10 epochs:: 7 and 8 in nvidia-smi
                                          
with strategy.scope():
    model = LeNet.build(input_shape=INPUT_SHAPE, classes=NB_CLASSES)
    model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
    history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs=10,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
end = time.time()
elapsed = end - start
time.strftime("%H:%M:%S", time.gmtime(elapsed))
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-21-0f96dd549fd3> in <module>
#       6
#       7 with strategy.scope():
# ----> 8     model = LeNet.build(input_shape=INPUT_SHAPE, classes=NB_CLASSES)
#       9     model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
#      10     history = model.fit(X_train, Y_train,
#
# <ipython-input-14-0fbc0240f266> in build(input_shape, classes)
#       5                 # CONV => RELU => POOL
#       6 		model.add(Conv2D(20, kernel_size=5, padding="same",
# ----> 7 			input_shape=input_shape))
#       8                 model.add(Activation("relu"))
#       9                 model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/sequential.py in add(self, layer)
#     176           # and create the node connecting the current layer
#     177           # to the input layer we just created.
# --> 178           layer(x)
#     179           set_inputs = True
#     180
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     815           # Build layer if applicable (if the `build` method has been
#     816           # overridden).
# --> 817           self._maybe_build(inputs)
#     818           cast_inputs = self._maybe_cast_inputs(inputs)
#     819
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2139         # operations.
#    2140         with tf_utils.maybe_init_scope(self):
# -> 2141           self.build(input_shapes)
#    2142       # We must set self.built since user defined build functions are not
#    2143       # constrained to set self.built.
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/convolutional.py in build(self, input_shape)
#     163         constraint=self.kernel_constraint,
#     164         trainable=True,
# --> 165         dtype=self.dtype)
#     166     if self.use_bias:
#     167       self.bias = self.add_weight(
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     520         collections=collections_arg,
#     521         synchronization=synchronization,
# --> 522         aggregation=aggregation)
#     523     backend.track_variable(variable)
#     524
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     742         dtype=dtype,
#     743         initializer=initializer,
# --> 744         **kwargs_for_getter)
#     745
#     746     # If we set an initializer and the variable processed it, tracking will not
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     137       synchronization=synchronization,
#     138       aggregation=aggregation,
# --> 139       shape=variable_shape if variable_shape else None)
#     140
#     141
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     256   def __call__(cls, *args, **kwargs):
#     257     if cls is VariableV1:
# --> 258       return cls._variable_v1_call(*args, **kwargs)
#     259     elif cls is Variable:
#     260       return cls._variable_v2_call(*args, **kwargs)
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     217         synchronization=synchronization,
#     218         aggregation=aggregation,
# --> 219         shape=shape)
#     220
#     221   def _variable_v2_call(cls,
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/ops/variables.py in getter(**kwargs)
#      63
#      64   def getter(**kwargs):
# ---> 65     return captured_getter(captured_previous, **kwargs)
#      66
#      67   return getter
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/distribute/distribute_lib.py in creator_with_resource_vars(*args, **kwargs)
#    1320         kwargs["initial_value"] = kwargs["initial_value"].wrapped_value
#    1321
# -> 1322       return self._create_variable(*args, **kwargs)
#    1323
#    1324     def distributed_getter(getter, *args, **kwargs):
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/distribute/mirrored_strategy.py in _create_variable(self, next_creator, *args, **kwargs)
#     524         self._container_strategy(), device_map, logical_device,
#     525         _real_mirrored_creator, values.MirroredVariable,
# --> 526         values.SyncOnReadVariable, *args, **kwargs)
#     527
#     528   def _validate_colocate_with_variable(self, colocate_with_variable):
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/distribute/distribute_lib.py in create_mirrored_variable(strategy, device_map, logical_device, real_mirrored_creator, mirrored_cls, sync_on_read_cls, *args, **kwargs)
#    2286   with tape.stop_recording():
#    2287     devices = device_map.logical_to_actual_devices(logical_device)
# -> 2288     value_list = real_mirrored_creator(devices, *args, **kwargs)
#    2289
#    2290     var_cls = sync_on_read_cls if is_sync_on_read else mirrored_cls
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/distribute/mirrored_strategy.py in _real_mirrored_creator(devices, *args, **kwargs)
#     499       value_list = []
#     500       for i, d in enumerate(devices):
# --> 501         with ops.device(d):
#     502           kwargs["initial_value"] = self._get_variable_creator_initial_value(
#     503               replica_id=i,
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in device(device_name_or_function)
#    5130           "tf.device does not support functions when eager execution "
#    5131           "is enabled.")
# -> 5132     return context.device(device_name_or_function)
#    5133   elif executing_eagerly_outside_functions():
#    5134     @tf_contextlib.contextmanager
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in device(name)
#    1687     Context manager for setting the device.
#    1688   """
# -> 1689   ensure_initialized()
#    1690   return context().device(name)
#    1691
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in ensure_initialized()
#    1581 def ensure_initialized():
#    1582   """Initialize the context."""
# -> 1583   context().ensure_initialized()
#    1584
#    1585
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in ensure_initialized(self)
#     480       opts = pywrap_tensorflow.TFE_NewContextOptions()
#     481       try:
# --> 482         config_str = self.config.SerializeToString()
#     483         pywrap_tensorflow.TFE_ContextOptionsSetConfig(opts, config_str)
#     484         if self._device_policy is not None:
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in config(self)
#     877
#     878     # Configure gpu_options
# --> 879     gpu_options = self._compute_gpu_options()
#     880     config.gpu_options.MergeFrom(gpu_options)
#     881
#
# ~/.conda/envs/keras-gpu/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py in _compute_gpu_options(self)
#     929     if not virtual_devices and memory_growths:
#     930       if len(memory_growths) > 1:
# --> 931         raise ValueError("Memory growth cannot differ between GPU devices")
#     932       allow_growth = memory_growths.pop()
#     933     else:
#
# ValueError: Memory growth cannot differ between GPU devices

# %% [markdown]
# Step 10: Evaluate the model on the test dataset (10,000 images)

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op GeneratorDataset in device /job:localhost/replica:0/task:0/device:GPU:6
# Executing op GeneratorDataset in device /job:localhost/replica:0/task:0/device:GPU:7
# Executing op __inference_distributed_function_17323 in device /job:localhost/replica:0/task:0/device:GPU:0
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 0.035459479167765276
# Test accuracy: 0.9896

# %% [markdown]
# Step 11: Plot the accuracy from history

# %%
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Step 12: Plot the loss from history

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# [Optional] Step 13: Save the model (serialized) to JSON

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# %ls
# Out:
# DeepLearningHelloWorldLeNet.ipynb        mnist_mlp_run.txt
# DeepLearningHelloWorldMNISTMLP.ipynb     model.h5
# GetAvailableGPUs.ipynb                   model.json
# KerasTutorialDeepLearninginPython.ipynb  README.md
# mnist_mlp.py

# %% [markdown]
# [Optional] Step 14: Save the model weights

# %%
model.save_weights("model.h5")
# %ls
# Out:
# DeepLearningHelloWorldLeNet.ipynb        mnist_mlp_run.txt
# DeepLearningHelloWorldMNISTMLP.ipynb     model.h5
# GetAvailableGPUs.ipynb                   model.json
# KerasTutorialDeepLearninginPython.ipynb  README.md
# mnist_mlp.py

# %% [markdown]
# [Optional] Step 15: Load the saved model

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("model.h5")
# Out:
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0

# %% [markdown]
# [Optional] Step 16: Compile and evaluate loaded model

# %%
loaded_model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
score = loaded_model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AnonymousIteratorV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_distributed_function_18667 in device /job:localhost/replica:0/task:0/device:GPU:0
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Executing op DeleteIterator in device /job:localhost/replica:0/task:0/device:CPU:0
#
# Test score: 0.035459479167765276
# Test accuracy: 0.9896

# %% [raw]
# - mkc
